# %% [markdown]
# # Exceptions

# %%
'''
try:
    do something()
except IOError:
    print("Can't import the local settings file.")
'''
# Out:
# '\ntry:\n    do something()\nexcept IOError:\n    print("Can\'t import the local settings file.")\n'

# %%
try:
    print("I'm trying")
    i = 1/0
except IOError:
    print("Nice try")
finally:
    print("What happens here?")
# Out:
# I'm trying
# What happens here?
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-129d058c3e3b> in <module>()
#       1 try:
#       2     print("I'm trying")
# ----> 3     i = 1/0
#       4 except IOError:
#       5     print("Nice try")
#
# ZeroDivisionError: division by zero
